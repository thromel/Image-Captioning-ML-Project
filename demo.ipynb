# %%
#import all the necessary libraries
from models.decoder import Decoder
from models.encoder import Encoder
from models.loss import loss_obj
from PIL import Image
import torch
import os
import numpy as np
import json
import pickle
from data_loader import get_loader

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/romel/github/Image-Captioning-ML-Project/demo.ipynb Cell 2 in <cell line: 9>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/romel/github/Image-Captioning-ML-Project/demo.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> caption = ''
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/romel/github/Image-Captioning-ML-Project/demo.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> for i in captions['annotations']:
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/romel/github/Image-Captioning-ML-Project/demo.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     if i['image_id'] == int(images[index].split('.')[0]):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/romel/github/Image-Captioning-ML-Project/demo.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         caption = i['caption']
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/romel/github/Image-Captioning-ML-Project/demo.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>         break
#
# ValueError: invalid literal for int() with base 10: 'COCO_val2014_000000461172'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
#Initialize bert
from pytorch_pretrained_bert import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
BertModel = BertModel.from_pretrained('bert-base-uncased').to(device)
BertModel.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): BertLayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
#Load vocabulary
print('Loading vocab...')
with open('data/vocab.pkl', 'rb') as f:
    vocab = pickle.load(f)
    print('Vocab size: ', len(vocab))
# Out:
# Loading vocab...
# Vocab size:  8853

# %%
val_loader = get_loader('val', vocab, 1)

#Pick a random image from the validation set
print(val_loader.dataset[0][0].shape)
# Out:
# loading annotations into memory...
# Done (t=0.30s)
# creating index...
# index created!
# torch.Size([3, 224, 224])

# %%
# %run demo.py
# Out:
# Loading vocabulary...
# Vocabulary loaded.
# loading annotations into memory...
# Done (t=0.58s)
# creating index...
# index created!
# /home/romel/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/romel/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Pre-Trained BERT Model
# Started generation...
#   0%|          | 0/25883 [00:00<?, ?it/s]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.6051416397094727]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a bedroom with a bed , bed , bed , a and and a on the bed .
# References: a bedroom with a bed , table , dresser , garbage can and towels on the bed .
#   0%|          | 1/25883 [00:03<23:57:01,  3.33s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a group of fruit on a table with <unk> and and in on it .
# References: a group of fruit on a table with eyes and <unk> drawn on them .
#   0%|          | 2/25883 [00:03<12:31:20,  1.74s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a bird bird with a green bird perched on a tree branch branch .
# References: a colorful bird with an orange beak sitting on a broken tree branch .
#   0%|          | 3/25883 [00:06<15:50:03,  2.20s/it]Lossy conversion from float32 to uint8. Range [-1.9637812376022339, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: man wearing in in black standing a hat standing in a kitchen
# References: man dressed in all black with a hat standing in someone 's kitchen
#   0%|          | 4/25883 [00:07<12:00:23,  1.67s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.4110641479492188]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a buses stopped at a bus station with passengers passengers .
# References: several buses pulled into a bus depot with passengers loading .
#   0%|          | 5/25883 [00:08<9:27:51,  1.32s/it] Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a group of men standing in a room with remotes .
# References: a group of men standing in a room with remotes .
#   0%|          | 6/25883 [00:09<8:05:44,  1.13s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.6051416397094727]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a living room of of a living with a tv .
# References: a living room area of a home with a tv .
#   0%|          | 7/25883 [00:09<7:14:19,  1.01s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a counter in in a store filled with lots . .
# References: a counter top in a store covered in bumper stickers .
#   0%|          | 8/25883 [00:10<6:33:14,  1.10it/s]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a kitchen with wood cabinets and wood cabinets . .
# References: a kitchen with wood cabinets and granite counter tops .
#   0%|          | 9/25883 [00:11<6:06:38,  1.18it/s]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a person in front of of a in cake .
# References: a mean in the middle of eating a pastry .
#   0%|          | 10/25883 [00:11<5:47:45,  1.24it/s]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: two people are a a boat on the water .
# References: three people ride in a speedboat on the water .
#   0%|          | 11/25883 [00:12<5:35:30,  1.29it/s]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a group is full of people and and . .
# References: a restaurant is full of people eating and chatting .
#   0%|          | 12/25883 [00:15<9:37:29,  1.34s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a man sitting on top of a wooden bench
# References: a man sitting on top of a wooden bench
#   0%|          | 13/25883 [00:16<8:24:13,  1.17s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a bus bus sits at a red light .
# References: a city bus waits at a red light .
#   0%|          | 14/25883 [00:16<7:27:28,  1.04s/it]Lossy conversion from float32 to uint8. Range [-2.1179039478302, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a man in a counter preparing for people .
# References: a man behind a counter serving many customers .
#   0%|          | 15/25883 [00:17<6:29:49,  1.11it/s]Lossy conversion from float32 to uint8. Range [-1.9656862020492554, 2.640000104904175]. Convert image to uint8 prior to saving to suppress this warning.
# Hypotheses: a image of bathroom bathroom with white toilet
# References: an image of bathroom setting with white toilet
#   0%|          | 16/25883 [00:18<8:24:49,  1.17s/it]
# Hypotheses: a close up a picture bird a a bird on the the 's .
# References: a close-up of a metal statue of a bird landing on the nest .
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/github/Image-Captioning-ML-Project/demo.py:228, in <module>
#     225 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     226 vocab, val_loader, encoder, decoder, decoder_optimizer = init_model(
#     227     device, mode='train')
# --> 228 generate_caption(vocab, device, encoder, decoder, val_loader)
#
# File ~/github/Image-Captioning-ML-Project/demo.py:220, in generate_caption(vocab, device, encoder, decoder, val_loader)
#     217     all_alphas.append(alphas)
#     218     all_imgs.append(imgs_jpg)
# --> 220 print_sample(vocab, hypotheses, references, test_references,
#     221              all_imgs, all_alphas, i, False)
#
# File ~/github/Image-Captioning-ML-Project/demo.py:135, in print_sample(vocab, hypotheses, references, test_references, imgs, alphas, k, show_att)
#     132 print('Hypotheses: '+" ".join(hyp_sentence))
#     133 print('References: '+" ".join(ref_sentence))
# --> 135 img = imgs[0][k]
#     136 imageio.imwrite('img.jpg', img)
#     138 if show_att:
#
# IndexError: index 16 is out of bounds for axis 0 with size 16
